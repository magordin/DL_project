# %%
import anndata as ad
import pandas as pd
from pathlib import Path
import shutil
import os

# %%
source_path = Path("/work3/s252608/DL_project/data/raw")

# %%
bulk_adata = ad.read_h5ad(f'{source_path}/bulk_processed_transcripts.h5ad')
